# %%
require(tidyverse)
require(feather)
require(stringdist)

data_folder_path <- "C:\\Users\\javier\\WorkSpace"

# %% [markdown]
# # Load ICD10fi and ICD10who

# %%
# load ICD10fi
thl_icd10fi <- read_feather(file.path(data_folder_path,
                                      "ICD10fi",
                                      "THL_ICD10fi.feather") )

# %%
# load concept table and get the ICD10who
concept <- read_feather(file.path(data_folder_path,
                                      "OMOP_vocabulary_v5",
                                      "CONCEPT.feather") )
concept_icd10 <- concept  %>% filter(vocabulary_id == "ICD10")

# %% [markdown]
# # Study codes

# %% [markdown]
# **Summary ICD10fi coding marks**
#
# In the Finnish version of the ICD10 there are two types of additional codes.
#
# - Classification codes: decrive ranges of codes other than the conventional ICD10 herarchy
#     - `Code1-Code2` : from Code1 to Code2
# - Reason codes: combine codes to add more info on what caused the diagnose, there are 4 marks
#    - `Code1*Code2` : ”Oirekoodi”, Code2 indicates an additional symtom
#    - `Code1+Code2` : ”Syykoodi”, Code2 indicates the reason for Code1
#    - `Code1#Code2` : ATC-koodi, Code2 is and ATC code indicating the medicine that caused Code1
#    - `Code1&Code2` : ”Kasvainkoodi”, Code2 is and endocrinological disorder code that caused Code1

# %% [markdown]
# ### How many are  clasification codes??

# %%
thl_icd10fi  %>% nrow
# Out:
# [1] 14681

# %%
thl_icd10fi  %>% distinct(CodeId)  %>% nrow
# Out:
# [1] 14681

# %%
thl_icd10fi_classif <- thl_icd10fi  %>% filter( grepl("-", CodeId))

# %%
thl_icd10fi_classif  %>% nrow
# Out:
# [1] 298

# %% [markdown]
# ### How many are a direct match ??

# %%
# match ICD10fi codes to the ICD10who codes 
thl_icd10fi_match_icd10who <- inner_join(thl_icd10fi,
                concept_icd10 %>% rename(CodeId = concept_code),
                by = "CodeId")

# %%
thl_icd10fi_match_icd10who %>% nrow
# Out:
# [1] 9587

# %% [markdown]
# #### Do these agree in the definitio ??

# %%
# Count the differes in the number of charactes between the english names b
thl_icd10fi_match_icd10who  %>%  select(CodeId, English_name, concept_name, ShortName) %>% 
        mutate(same_name = stringdist(English_name,concept_name) )  %>% 
        count(same_name, sort = T) #%>% head(10)
# Out:
#     same_name n
# 1    0        8463
# 2   NA         226
# 3    2         150
# 4    3         149
# 5   20         114
# 6    4          91
# 7    1          84
# 8    7          32
# 9   17          26
# 10  10          20
# 11   5          18
# 12  14          14
# 13  37          13
# 14  42          13
# 15  15          12
# 16  19          12
# 17  39          12
# 18  22          11
# 19  45          11
# 20  59          10
# 21  18           8
# 22   8           7
# 23  32           6
# 24   6           5
# 25  16           5
# 26  27           5
# 27   9           4
# 28  11           4
# 29  12           4
# 30  24           4
# ... ...       ...
# 32  13        3
# 33  23        3
# 34  28        3
# 35  29        3
# 36  38        3
# 37  40        3
# 38  43        3
# 39  21        2
# 40  25        2
# 41  33        2
# 42  36        2
# 43  44        2
# 44  47        2
# 45  30        1
# 46  35        1
# 47  41        1
# 48  46        1
# 49  48        1
# 50  49        1
# 51  52        1
# 52  55        1
# 53  56        1
# 54  57        1
# 55  58        1
# 56  61        1
# 57  64        1
# 58  65        1
# 59  74        1
# 60  76        1
# 61  77        1

# %% [markdown]
# Most 8463 match the name exatly, 226 NA for these with no english name

# %% [markdown]
# #### Why the large differences ??

# %%
# Count the differes in the number of charactes between the english names b
thl_icd10fi_match_icd10who  %>%  select(CodeId, English_name, concept_name, ShortName) %>% 
        mutate(same_name = stringdist(English_name,concept_name) )  %>% 
        rename(ICD10fi_name = English_name, ICD10who_name = concept_name) %>% 
        filter(same_name>21)
# Out:
#     CodeId
# 1   A09
# 2   A49.1
# 3   A74.0
# 4   B96.5
# 5   C81.1
# 6   C81.2
# 7   C81.3
# 8   C82
# 9   C83.6
# 10  C83.9
# 11  C84
# 12  C84.4
# 13  C90.2
# 14  C91.5
# 15  C92.1
# 16  C92.2
# 17  C96.0
# 18  D39.1
# 19  D47.2
# 20  D76
# 21  E11.1
# 22  E11.5
# 23  E11.6
# 24  E11.7
# 25  E11.8
# 26  E11.9
# 27  F66.8
# 28  F79.9
# 29  G23.1
# 30  G23.2
# ... ...
# 105 R89.5
# 106 R89.6
# 107 R89.7
# 108 R89.8
# 109 R89.9
# 110 T81.0
# 111 U06.9
# 112 U07.1
# 113 W01
# 114 W31
# 115 W68
# 116 V10.2
# 117 V10.9
# 118 V11
# 119 V11.2
# 120 V11.9
# 121 V14.2
# 122 V14.9
# 123 V16.2
# 124 V16.9
# 125 V28.2
# 126 V28.9
# 127 V48.2
# 128 V48.9
# 129 V87
# 130 V88
# 131 Y57
# 132 Y58
# 133 Y59
# 134 Z74.0
#     ICD10fi_name
# 1   Diarrhoea and gastroenteritis of presumed infectious origin
# 2   Streptococcal infection, unspecified
# 3   Paratrachoma
# 4   Pseudomonas (aeruginosa)(mallei)(pseudomallei) as the cause of diseases classified to other chapters
# 5   Nodular sclerosis
# 6   Mixed cellularity
# 7   Lymphocytic depletion
# 8   Follicular [nodular] non-Hodgkin's lymphoma
# 9   Undifferentiated (diffuse)
# 10  Diffuse non-Hodgkin's lymphoma, unspecified
# 11  Peripheral and cutaneous T-cell lymphomas
# 12  Peripheral T-cell lymphoma
# 13  Plasmacytoma, extramedullary
# 14  Adult T-cell leukaemia
# 15  Chronic myeloid leukaemia
# 16  Subacute myeloid leukaemia
# 17  Letterer-Siwe disease
# 18  Ovary
# 19  Monoclonal gammopathy
# 20  Certain diseases involving lymphoreticular tissue and reticulohistiocytic system
# 21  Non-insulin-dependent diabetes mellitus - With ketoacidosis
# 22  Non-insulin-dependent diabetes mellitus - With peripheral circulatory complications
# 23  Non-insulin-dependent diabetes mellitus - With other specified complications
# 24  Non-insulin-dependent diabetes mellitus - With multiple complications
# 25  Non-insulin-dependent diabetes mellitus - With unspecified complications
# 26  Non-insulin-dependent diabetes mellitus - Without complications
# 27  Other specified disorders of psychosexual development
# 28  Unspecified mental retardation
# 29  Progressive supranuclear ophthalmoplegia
# 30  Striatonigral degeneration
# ... ...
# 105 Abnormal findings in nipple discharge synovial fluid wound secretions - Abnormal microbiological findings
# 106 Abnormal findings in nipple discharge synovial fluid wound secretions - Abnormal cytological findings
# 107 Abnormal findings in nipple discharge synovial fluid wound secretions - Abnormal histological findings
# 108 Abnormal findings in nipple discharge synovial fluid wound secretions - Other abnormal findings
# 109 Abnormal findings in nipple discharge synovial fluid wound secretions - Unspecified abnormal finding
# 110 Haemorrhage at any site resulting from a procedure
# 111 Zika virus disease, unspecified
# 112 2019-nCoV acute respiratory disease
# 113 Fall on same level
# 114 Contact with machinery
# 115 Drowning and submersion in swimming-pool or bath
# 116 Pedal cyclist injured in collision with pedestrian or animal
# 117 Pedal cyclist injured in collision with pedestrian or animal
# 118 Pedal cyclist injured in collision with other pedal cycle or other nonmotor vehicle
# 119 Pedal cyclist injured in collision with other pedal cycle other nonmotor vehicle
# 120 Pedal cyclist injured in collision with other pedal cycle or other nonmotor vehicle
# 121 Pedal cyclist injured in collision with motor vehicle
# 122 Pedal cyclist injured in collision with motor vehicle
# 123 Pedal cyclist injured in collision with train or tram - Unspecified or nontraffic accident
# 124 Pedal cyclist injured in collision with train or tram - Traffic accident
# 125 Motorcycle rider injured in noncollision transport accidents unspecified or nontraffic accident
# 126 Motorcycle rider injured in noncollision transport accidents traffic accident
# 127 Car occupant injured in noncollision transport accident unspecified or nontraffic accident
# 128 Car occupant injured in noncollision transport accident traffic accident
# 129 Motor- or nonmotor-vehicle accident, type of vehicle unspecified
# 130 Motor- or nonmotor-vehicle accident, type of vehicle unspecified - non-traffic accident
# 131 Other and unspecified drugs and medicaments
# 132 Bacterial vaccines
# 133 Other and unspecified vaccines and biological substances
# 134 Reduced mobility
#     ICD10who_name
# 1   Other gastroenteritis and colitis of infectious and unspecified origin
# 2   Streptococcal and enterococcal infection, unspecified site
# 3   Chlamydial conjunctivitis
# 4   Pseudomonas (aeruginosa) as the cause of diseases classified to other chapters
# 5   Nodular sclerosis classical Hodgkin lymphoma
# 6   Mixed cellularity classical Hodgkin lymphoma
# 7   Lymphocyte depleted classical Hodgkin lymphoma
# 8   Follicular lymphoma
# 9   Undifferentiated (diffuse) non-Hodgkin's lymphoma
# 10  Non-follicular (diffuse) lymphoma, unspecified
# 11  Mature T/NK-cell lymphomas
# 12  Peripheral T-cell lymphoma, not elsewhere classified
# 13  Extramedullary plasmacytoma
# 14  Adult T-cell lymphoma/leukaemia [HTLV-1-associated]
# 15  Chronic myeloid leukaemia [CML], BCR/ABL-positive
# 16  Atypical chronic myeloid leukaemia, BCR/ABL- negative
# 17  Multifocal and multisystemic (disseminated) Langerhans-cell histiocytosis [Letterer-Siwe disease]
# 18  Neoplasm of uncertain or unknown behaviour: Ovary
# 19  Monoclonal gammopathy of undetermined significance (MGUS)
# 20  Other specified diseases with participation of lymphoreticular and reticulohistiocytic tissue
# 21  Type 2 diabetes mellitus, with ketoacidosis
# 22  Type 2 diabetes mellitus, with peripheral circulatory complications
# 23  Type 2 diabetes mellitus, with other specified complications
# 24  Type 2 diabetes mellitus, with multiple complications
# 25  Type 2 diabetes mellitus, with unspecified complications
# 26  Type 2 diabetes mellitus, without complications
# 27  Other psychosexual development disorders
# 28  Unspecified mental retardation, without mention of impairment of behaviour
# 29  Progressive supranuclear ophthalmoplegia [Steele-Richardson-Olszewski]
# 30  Multiple system atrophy, parkinsonian type [MSA-P]
# ... ...
# 105 Abnormal findings in specimens from other organs, systems and tissues, abnormal microbiological findings
# 106 Abnormal findings in specimens from other organs, systems and tissues, abnormal cytological findings
# 107 Abnormal findings in specimens from other organs, systems and tissues, abnormal histological findings
# 108 Abnormal findings in specimens from other organs, systems and tissues, other abnormal findings
# 109 Abnormal findings in specimens from other organs, systems and tissues, unspecified abnormal finding
# 110 Haemorrhage and haematoma complicating a procedure, not elsewhere classified
# 111 Emergency use of U06.9
# 112 Emergency use of U07.1
# 113 Fall on same level from slipping, tripping and stumbling
# 114 Contact with other and unspecified machinery
# 115 Drowning and submersion following fall into swimming-pool
# 116 Pedal cyclist injured in collision with pedestrian or animal, Unspecified pedal cyclist injured in nontraffic accident
# 117 Pedal cyclist injured in collision with pedestrian or animal, Unspecified pedal cyclist injured in traffic accident
# 118 Pedal cyclist injured in collision with other pedal cycle
# 119 Pedal cyclist injured in collision with other pedal cycle, unspecified pedal cyclist injured in nontraffic accident
# 120 Pedal cyclist injured in collision with other pedal cycle, unspecified pedal cyclist injured in traffic accident
# 121 Pedal cyclist injured in collision with heavy transport vehicle or bus, unspecified pedal cyclist injured in nontraffic accident
# 122 Pedal cyclist injured in collision with heavy transport vehicle or bus, unspecified pedal cyclist injured in traffic accident
# 123 Pedal cyclist injured in collision with other nonmotor vehicle, unspecified pedal cyclist injured in nontraffic accident
# 124 Pedal cyclist injured in collision with other nonmotor vehicle, unspecified pedal cyclist injured in traffic accident
# 125 Motorcycle rider injured in noncollision transport accident, unspecified motorcycle rider injured in nontraffic accident
# 126 Motorcycle rider injured in noncollision transport accident, unspecified motorcycle rider injured in traffic accident
# 127 Car occupant injured in noncollision transport accident, person on outside of vehicle injured in nontraffic accident
# 128 Car occupant injured in noncollision transport accident, unspecified car occupant injured in traffic accident
# 129 Traffic accident of specified type but victim's mode of transport unknown
# 130 Nontraffic accident of specified type but victim's mode of transport unknown
# 131 Adverse effects in the therapeutic use of other and unspecified drugs and medicaments
# 132 Adverse effects in the therapeutic use of bacterial vaccines
# 133 Adverse effects in the therapeutic use of other and unspecified vaccines and biological substances
# 134 Need for assistance due to reduced mobility
#     ShortName                                          same_name
# 1   Tartt. olet. ripuli/g-e-iitti                      40
# 2   Streptokokki, sij ei-määr                          22
# 3   Paratrakooma                                       22
# 4   Pseudomonakset sair. aih.                          22
# 5   Sidekudoskyhmyinen Hodgkinin t                     27
# 6   Sekasoluinen Hodgkinin tauti                       27
# 7   Vähälymfosyyttinen Hodgkinin t                     28
# 8   Nodul. non-Hodgkin-lymfooma                        24
# 9   Diff.non-Hodgk,erilaistum.solu                     23
# 10  Diff.non-Hodgkin-lymfooma NAS                      22
# 11  Perif./ihon T-solulymfoomat                        23
# 12  Perifeerinen T-solulymfooma                        26
# 13  Ekstramedull. plasmosytooma                        24
# 14  Aikuisen T-soluleukemia                            29
# 15  Kroon. myelooinen leukemia                         24
# 16  Subakuutt. myelooinen leukemia                     33
# 17  Disseminoitunut langerhansinsoluhistiosytoosi      76
# 18  Munasarjan epäs. kasvain                           44
# 19  Monoklonaalinen gammapatia                         36
# 20  Eräät lymforetik.kudoksen sair                     42
# 21  Aik.diabetes ketoasidoosi                          22
# 22  Aik.diabetes ääreisverenk.häir                     22
# 23  Aik.diabetes muu komplikaatio                      22
# 24  Aik.diabetes us.komplikaatioit                     22
# 25  Aik.diabetes komplikaatiot NAS                     22
# 26  Aik.diabetes ei komplikaatioit                     22
# 27  Muut määritetty psykoseks keh.                     33
# 28  Älyll.keh.v.NAS ei tiet.käytös                     44
# 29  Eten.supranukl.silmälihashalv                      30
# 30  Monisysteemiatrofian parkinsonistinen alatyyppi    42
# ... ...                                                ...
# 105 Muiden näytt.poikk.viljelylöyd                     45
# 106 Muiden näytt.poikk.sytol.löyd                      45
# 107 Muiden näytt.poikk.histol.löyd                     45
# 108 Muiden näytt.muut poikk.löydök                     45
# 109 Muiden näytt.poikk.löydös NAS                      45
# 110 Toim.pit. johtuva verenvuoto                       47
# 111 Zikavirusinfektio, määrittämätön                   27
# 112 2019-nCoV-viruksen aih. äkillinen hengitystietul.  29
# 113 Liukastum/kompastum/kompuroim                      38
# 114 Kone,muu/NAS, tapaturma                            22
# 115 Vajoam.uima-alt.putoam.seurauk                     25
# 116 Pyöräilytapaturma jalankulkijan tai eläimen kanss  58
# 117 Pyöräilytapaturma jalankulkijan tai eläimen kanssa 55
# 118 Pyöräilytapaturma toisen polkupyörän tai muun moot 26
# 119 Pyöräilytapaturma toisen polkupyörän tai muun moot 49
# 120 Pyöräilytapaturma toisen polkupyörän tai muun moot 46
# 121 Pyöräilytapaturma moottoriajoneuvon kanssa liiken  77
# 122 Pyöräilytapaturma moottoriajoneuvon kanssa liiken  74
# 123 Polkupyöräilijän juna- tai raitiovaunutapaturma l  41
# 124 Polkupyöräilijän juna- tai raitiovaunutapaturma l  52
# 125 Moottoripyörätapaturma törmäämättä toiseen liikkuv 26
# 126 Moottoripyörätapaturma törmäämättä toiseen liikkuv 40
# 127 Henkilöautotapaturma törmäämättä toiseen liikkuvaa 32
# 128 Henkilöautotapaturma törmäämättä toiseen liikkuvaa 37
# 129 Määrittämätön liikennetapaturma liikennealueella   61
# 130 Määrittämätön liikennetapaturma liikennealueen ulk 64
# 131 Lääkk,muu/NAS,haittavaikutukse                     43
# 132 Bakteerirokott.haittavaikutuks                     43
# 133 Muiden rokott/biol.ain.haittav                     43
# 134 Liikuntarajoitteisuus                              28

# %% [markdown]
# Seems the concept are the same, descrived in different way.

# %% [markdown]
# ### How many more match if only the diagnose code is taken?

# %%
# match ICD10fi's diagnose codes to the ICD10who codes 
matched_ids <- c(thl_icd10fi_classif$CodeId, thl_icd10fi_match_icd10who$CodeId)

thl_icd10fi_code1_match_icd10who <- inner_join( thl_icd10fi  %>% filter(!(CodeId %in% matched_ids)) , 
                concept_icd10 %>% rename(Code1 = concept_code),
                by = "Code1")

# %%
thl_icd10fi_code1_match_icd10who  %>% nrow
# Out:
# [1] 2105

# %% [markdown]
# ### How many ICD10fi diagnose codes do not exist in ICD10who?

# %%
matched_ids <- c(thl_icd10fi_classif$CodeId, thl_icd10fi_match_icd10who$CodeId, thl_icd10fi_code1_match_icd10who$CodeId)

thl_icd10fi_new <- thl_icd10fi  %>% filter(!(CodeId %in% matched_ids))

# %%
# which not composed codes are new
thl_icd10fi_new %>%
select(CodeId, English_name, ShortName)
# Out:
#      CodeId
# 1    A28.10
# 2    A28.11
# 3    A28.19
# 4    A31.80
# 5    A31.81
# 6    A31.84
# 7    A31.89
# 8    A50.50
# 9    A50.51
# 10   A50.52
# 11   A50.54
# 12   A50.55
# 13   A50.59
# 14   A50.59+I98.0
# 15   A50.59+M03.1
# 16   A50.59+M90.2
# 17   A52.70
# 18   A52.71
# 19   A52.72
# 20   A52.73
# 21   A52.74
# 22   A52.75
# 23   A52.79
# 24   A52.79+H19.0
# 25   A52.79+H32.0
# 26   A52.79+H58.8
# 27   A52.79+J99.8
# 28   A52.79+K67.2
# 29   A52.79+K77.0
# 30   A52.79+L99.8
# ...  ...
# 2662 ZA1.0
# 2663 ZA2.0
# 2664 ZA3.0
# 2665 ZA4.0
# 2666 ZA5.0
# 2667 ZA5.1
# 2668 ZA6.0
# 2669 ZA7.0
# 2670 ZA8.0
# 2671 ZA8.1
# 2672 ZA8.2
# 2673 ZA8.3
# 2674 ZA8.4
# 2675 ZB0.0
# 2676 ZB0.1
# 2677 ZB0.2
# 2678 ZB1.0
# 2679 ZB1.1
# 2680 Z03.80
# 2681 Z03.89
# 2682 Z13.80
# 2683 Z13.81
# 2684 Z13.82
# 2685 Z13.88
# 2686 Z22.30
# 2687 Z22.38
# 2688 Z51.80
# 2689 Z51.88
# 2690 Z52.80
# 2691 Z52.89
#      English_name
# 1    NA
# 2    NA
# 3    NA
# 4    NA
# 5    NA
# 6    NA
# 7    Other mycobacterial infections
# 8    NA
# 9    NA
# 10   NA
# 11   NA
# 12   NA
# 13   Other late congenital syphilis, symptomatic
# 14   Late congenital cardiovascular syphilis+
# 15   Clutton's joints+
# 16   Late congenital syphilitic: osteochondropathy+
# 17   NA
# 18   NA
# 19   NA
# 20   NA
# 21   NA
# 22   NA
# 23   Other symptomatic late syphilis
# 24   Late syphilitic episcleritis+
# 25   Late syphilitic chorioretinitis+
# 26   Late syphilitic oculopathy NEC+
# 27   Syphilis [stage unspecified] of lung+
# 28   Syphilitic peritonitis
# 29   Syphilitic liver disease
# 30   Late syphilitic leukoderma+
# ...  ...
# 2662 Shoulder region
# 2663 Upper arm
# 2664 Forearm
# 2665 Hand
# 2666 Pelvic region
# 2667 Hip and thigh
# 2668 Lower leg
# 2669 Ankle and foot
# 2670 NA
# 2671 NA
# 2672 NA
# 2673 NA
# 2674 NA
# 2675 Left side
# 2676 Right side
# 2677 Bilateral
# 2678 Lateral
# 2679 Medial
# 2680 Observation for other suspected diseases and conditions
# 2681 Observation for other suspected diseases and conditions
# 2682 Screening for hypothyroidism
# 2683 Screening for phenylketonuria
# 2684 Screening for phenylketonuria
# 2685 Special screening examination for other specified diseases and disorders
# 2686 NA
# 2687 Carrier of other specified bacterium diseases
# 2688 NA
# 2689 Other specified medical care
# 2690 NA
# 2691 NA
#      ShortName
# 1    Kissanraapaisut suun al. ilm.
# 2    Kaulan imus. kissanraapaisut.
# 3    Muu tai määr. kissanraapaisut.
# 4    M.bact. intr.cell.tulehd.suus.
# 5    M.bact. chelonei tulehd. suu
# 6    Muu tai määr. mykobakt. aih
# 7    Muu mykobakt infektio
# 8    Kupan aih. Parrotin uurteet
# 9    Hutchinsonin etuhampaat
# 10   Nuppuhammas Mulberryn molaari
# 11   Muu määr. kupan suun al.ilm.
# 12   Tark.määrtön kupan suun ilm
# 13   Muu oir synn myöhäiskuppa
# 14   Myöh.kuppa, sydän-verisuonisai
# 15   Myöh.synn.syph.,nivelsairaus
# 16   Myöh. syphilis, luusairaus
# 17   Kupan aih. gumma suun kudoks
# 18   Kupan aiheuttama suulaen aukko
# 19   Kupan aiheuttama kielitulehdus
# 20   Kupan aih. leukojen osteomyel.
# 21   Muu .kupan suun alueen ilm
# 22   Määrittön suun alueen ilm
# 23   Muu oireinen myöhäiskuppa
# 24   Myöhäis kupan,skleriitti/episk
# 25   Sek. syphilis, korioretiniitt
# 26   Myöh.kuppa.muu silmän sair
# 27   Syphiliks.liitt.hengitysel.s
# 28   Myöhäiskuppa,vatsakalvotulehd
# 29   Kupan aiheuttama maksasairaus
# 30   Myöhäiskupan aih. leukoderma
# ...  ...
# 2662 Olkapään vika, vamma tai sairaus
# 2663 Olkavarren tai kyynärpään vika, vamma tai sairaus
# 2664 Kyynärvarren tai ranteen vika, vamma tai sairaus
# 2665 Käden vika, vamma tai sairaus
# 2666 Lantion vika, vamma tai sairaus
# 2667 Lonkkanivelen tai reiden vika, vamma tai sairaus
# 2668 Polven tai säären vika, vamma tai sairaus
# 2669 Nilkan tai jalkaterän vika, vamma tai sairaus
# 2670 Kallon vika, vamma tai sairaus
# 2671 Kasvojen vika, vamma tai sairaus
# 2672 Kaulan tai niskan vika, vamma tai sairaus
# 2673 Rintakehän alueen vika, vamma tai sairaus
# 2674 Lannerangan vika, vamma tai sairaus
# 2675 Vasemman puoleinen
# 2676 Oikean puoleinen
# 2677 Molemmin puoleinen
# 2678 Lateraalinen
# 2679 Mediaalinen
# 2680 Endokriinisen sairauden epäill
# 2681 Tarkkailu,muu sairausepäily
# 2682 Vastasynt.hypotyreoosinseulont
# 2683 Neonat.fenylketonuriaseulonta
# 2684 Muu vastasyntyneen seulonta
# 2685 Muun sair/häir.seulontatutkimu
# 2686 Latentti tuberkuloosi
# 2687 Muun bakteerin kantajuus
# 2688 Murrosiän kehityksen muuttaminen hormonihoidolla
# 2689 Muu lääketieteellinen hoito
# 2690 Keuhkon luovuttaja
# 2691 Muun elimen luovuttaja

# %%
#which are new in the level higher than 6
thl_icd10fi_new  %>% 
select(CodeId, English_name, ShortName) %>% 
mutate(group = nchar(CodeId) #str_sub(concept_code, 0, 1)
      ) %>% filter(group<6)
# Out:
#     CodeId
# 1   B07.9
# 2   F61.0
# 3   F61.1
# 4   W71
# 5   X85.0
# 6   X85.2
# 7   X85.8
# 8   X85.9
# 9   X90.0
# 10  X90.2
# 11  X90.8
# 12  X90.9
# 13  X91.0
# 14  X91.2
# 15  X91.8
# 16  X91.9
# 17  X92.0
# 18  X92.2
# 19  X92.8
# 20  X92.9
# 21  X93.0
# 22  X93.2
# 23  X93.8
# 24  X93.9
# 25  X94.0
# 26  X94.2
# 27  X94.8
# 28  X94.9
# 29  X95.0
# 30  X95.2
# ... ...
# 54  Y94.0
# 55  Y94.1
# 56  Y94.2
# 57  Y94.4
# 58  Y94.5
# 59  Y94.8
# 60  Y95.0
# 61  Y96.0
# 62  Y96.2
# 63  Y96.8
# 64  Y96.9
# 65  ZA0.0
# 66  ZA1.0
# 67  ZA2.0
# 68  ZA3.0
# 69  ZA4.0
# 70  ZA5.0
# 71  ZA5.1
# 72  ZA6.0
# 73  ZA7.0
# 74  ZA8.0
# 75  ZA8.1
# 76  ZA8.2
# 77  ZA8.3
# 78  ZA8.4
# 79  ZB0.0
# 80  ZB0.1
# 81  ZB0.2
# 82  ZB1.0
# 83  ZB1.1
#     English_name
# 1   Verruca simplex
# 2   Mixed personality disorders
# 3   NA
# 4   Drowning to ice
# 5   Assault by drugs, medicaments and biological substances by spouse or partner
# 6   Assault by drugs, medicaments and biological substances by friend
# 7   Assault by drugs, medicaments and biological substances by other known person
# 8   Assault by drugs, medicaments and biological substances by unknown person
# 9   Assault by unspecified chemical or noxious substance by spouse or partner
# 10  Assault by unspecified chemical or noxious substance by friend
# 11  Assault by unspecified chemical or noxious substance by other known person
# 12  Assault by unspecified chemical or noxious substance by unknown person
# 13  Assault by hanging, strangulation and suffocation by spouse or partner
# 14  Assault by hanging, strangulation and suffocation by friend
# 15  Assault by hanging, strangulation and suffocation by other known person
# 16  Assault by hanging, strangulation and suffocation by unknown person
# 17  Assault by drowning and submersion by spouse or partner
# 18  Assault by drowning and submersion by friend
# 19  Assault by drowning and submersion other specified person
# 20  Assault by drowning and submersion by unknown person
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  Assault by other and unspecified firearm discharge by spouse or partner
# 30  Assault by other and unspecified firearm discharge by friend
# ... ...
# 54  Accident at home
# 55  NA
# 56  Accident with sport
# 57  NA
# 58  NA
# 59  Other leisure activity accident
# 60  Accident in a hospital or hospital associated external cause
# 61  Work-related condition
# 62  School or kindergarten related condition
# 63  Other type of accident
# 64  Unspecified type of accident
# 65  Multiple sites
# 66  Shoulder region
# 67  Upper arm
# 68  Forearm
# 69  Hand
# 70  Pelvic region
# 71  Hip and thigh
# 72  Lower leg
# 73  Ankle and foot
# 74  NA
# 75  NA
# 76  NA
# 77  NA
# 78  NA
# 79  Left side
# 80  Right side
# 81  Bilateral
# 82  Lateral
# 83  Medial
#     ShortName                                          group
# 1   Tavallinen syylä                                   5
# 2   Sekamuotoiset persoonallisuushäiriöt               5
# 3   Häiritsevä persoonallisuusmuutos                   5
# 4   Vajoaminen jäihin                                  3
# 5   Pahoinpitely lääkeaineilla.0                       5
# 6   Pahoinpitely lääkeaineilla.2                       5
# 7   Pahoinpitely lääkeaineilla.8                       5
# 8   Pahoinpitely lääkeaineilla.9                       5
# 9   Pahoinpit.kem.aineilla NAS.0                       5
# 10  Pahoinpit.kem.aineilla NAS.2                       5
# 11  Pahoinpit.kem.aineilla NAS.8                       5
# 12  Pahoinpit.kem.aineilla NAS.9                       5
# 13  Pahoinpitely tukehduttamall.0                      5
# 14  Pahoinpitely tukehduttamall.2                      5
# 15  Pahoinpitely tukehduttamall.8                      5
# 16  Pahoinpitely tukehduttamall.9                      5
# 17  Pahoinpit.upott/hukuttamall.0                      5
# 18  Pahoinpit.upott/hukuttamall.2                      5
# 19  Pahoinpit.upott/hukuttamall.8                      5
# 20  Pahoinpit.upott/hukuttamall.9                      5
# 21  Ampumalla pist.revolv, murha yms, partneri         5
# 22  Ampumalla pist.revolv, murha yms, tuttava          5
# 23  Ampumalla pist.revolv, murha yms, muu              5
# 24  Ampumalla pist.revolv, murha yms, tuntematon       5
# 25  Ampumalla järeällä aseella, murha yms, partneri    5
# 26  Ampumalla järeällä aseella, murha yms, tuttava     5
# 27  Ampumalla järeällä aseella, murha yms, muu         5
# 28  Ampumalla järeällä aseella, murha yms, tuntematon  5
# 29  Pahoinpit.ampumalla,muu/NAS.0                      5
# 30  Pahoinpit.ampumalla,muu/NAS.2                      5
# ... ...                                                ...
# 54  Kotitapaturma                                      5
# 55  Palveluasumis tapaturma                            5
# 56  Urheilu tai liikuntatapaturma                      5
# 57  Tapaturma liikennealueella                         5
# 58  Ravintolatapaturma                                 5
# 59  Muu vapaa-ajan tapaturma                           5
# 60  Sairaalaoloihin liitt.tila                         5
# 61  Työhön liittyvä ulk. tekijä                        5
# 62  Tapaturma koulussa tai päiväkodissa                5
# 63  Muun tyyppinen tapaturma                           5
# 64  Määrittämätön tapaturmatyyppi                      5
# 65  Monissa paikoissa ilmenevä vika, vamma tai sairaus 5
# 66  Olkapään vika, vamma tai sairaus                   5
# 67  Olkavarren tai kyynärpään vika, vamma tai sairaus  5
# 68  Kyynärvarren tai ranteen vika, vamma tai sairaus   5
# 69  Käden vika, vamma tai sairaus                      5
# 70  Lantion vika, vamma tai sairaus                    5
# 71  Lonkkanivelen tai reiden vika, vamma tai sairaus   5
# 72  Polven tai säären vika, vamma tai sairaus          5
# 73  Nilkan tai jalkaterän vika, vamma tai sairaus      5
# 74  Kallon vika, vamma tai sairaus                     5
# 75  Kasvojen vika, vamma tai sairaus                   5
# 76  Kaulan tai niskan vika, vamma tai sairaus          5
# 77  Rintakehän alueen vika, vamma tai sairaus          5
# 78  Lannerangan vika, vamma tai sairaus                5
# 79  Vasemman puoleinen                                 5
# 80  Oikean puoleinen                                   5
# 81  Molemmin puoleinen                                 5
# 82  Lateraalinen                                       5
# 83  Mediaalinen                                        5

# %%
# what groups have more new ones 
thl_icd10fi_new  %>% 
select(CodeId, English_name, ShortName) %>% 
mutate(group = str_sub(CodeId, 0, 1)) %>% count(group, sort = T)
# Out:
#    group n
# 1  C     770
# 2  F     497
# 3  Q     348
# 4  K     313
# 5  D     130
# 6  I     105
# 7  E      89
# 8  G      62
# 9  H      50
# 10 X      48
# 11 A      39
# 12 Y      36
# 13 B      35
# 14 S      32
# 15 Z      31
# 16 P      26
# 17 N      16
# 18 O      16
# 19 L      15
# 20 J      10
# 21 R      10
# 22 T       7
# 23 M       3
# 24 V       2
# 25 W       1

# %% [markdown]
# # Proposed matching
#
# 1. Ignore the new ICD10fi clasification codes, these are not supose to be used as diagnose
# 2. Match ICD10fi to ICD10who only based on the diagnose code `code1`
# 3. These new ICD10fi that dont exist in ICD10who, match to the parent code

# %%
# ICD10fi code mathches the ICD10who
thl_icd10fi_clas <- thl_icd10fi  %>% 
    filter( CodeId %in% concept_icd10$concept_code)  %>% 
    mutate( ICD10who = CodeId , ICD10who_match_level = 0 )

# %%
# match diagnose codes to the upper level code
thl_icd10fi_new_1 <- inner_join( thl_icd10fi_new  %>% 
                                # remove the last digit of the code 
                                mutate(ICD10who = str_sub(Code1, 0, -2))%>% 
                                # remove the last digit of the code if it is a point
                                mutate(ICD10who = sub("\\.$", "", ICD10who)) , 
                concept_icd10 %>% rename(ICD10who = concept_code),
                by = "ICD10who")

# %%
thl_icd10fi_new_1  %>%  nrow
# Out:
# [1] 2587

# %%
# match diagnose codes to the upper level code
thl_icd10fi_new_2 <- left_join( thl_icd10fi_new  %>% filter( !(CodeId %in% thl_icd10fi_new_1$CodeId)) %>%  
                                # remove the last digit of the code 
                                mutate(ICD10who = str_sub(Code1, 0, -3))%>% 
                                # remove the last digit of the code if it is a point
                                mutate(ICD10who = sub("\\.$", "", ICD10who)) , 
                concept_icd10 %>% rename(ICD10who = concept_code),
                by = "ICD10who")

# %%
thl_icd10fi_new_2 %>%  nrow
# Out:
# [1] 104

# %%
# Join all 
thl_icd10fi_matched <- bind_rows(
    # classifiction codes
    thl_icd10fi  %>% filter( CodeId %in%thl_icd10fi_classif$CodeId)  %>% 
    mutate(ICD10who = as.character(NA), ICD10who_match_level = "classification" ), 
    # perfect matches
    thl_icd10fi  %>% filter( CodeId %in%thl_icd10fi_match_icd10who$CodeId)  %>% 
    mutate(ICD10who = CodeId, ICD10who_match_level = "full_match" ), 
    # matched with the diagnose 
    thl_icd10fi  %>% filter( CodeId %in%thl_icd10fi_code1_match_icd10who$CodeId)  %>% 
    mutate(ICD10who = Code1, ICD10who_match_level = "diagnose_match" ),
    #
    thl_icd10fi_new_1 %>% select(CodeId:ICD10who)%>% 
    mutate(ICD10who_match_level = "diagnose_match_parent" ),
    #
    thl_icd10fi_new_2 %>% select(CodeId:ICD10who)%>% 
    mutate(ICD10who_match_level =  "diagnose_match_grandparent" )
)%>% arrange(CodeId)  %>% 
mutate(ICD10who_match_level = factor(ICD10who_match_level, 
                                     levels = c("classification", 
                                                "full_match", 
                                                "diagnose_match",
                                                "diagnose_match_parent", 
                                                "diagnose_match_grandparent")
                                    )
      )

# %%
thl_icd10fi_matched  %>% count(ICD10who_match_level)
# Out:
#   ICD10who_match_level       n
# 1 classification              298
# 2 full_match                 9587
# 3 diagnose_match             2105
# 4 diagnose_match_parent      2587
# 5 diagnose_match_grandparent  104

# %%
# load ICD10fi
write_feather(thl_icd10fi_matched, file.path(data_folder_path,
                                      "ICD10fi",
                                      "THL_ICD10fi_matched_ICD10who.feather") )
