# %%
require(tidyverse)
require(feather)
require(readxl)
require(lubridate)

folder_path <-"C:\\Users\\javier\\WorkSpace\\ICD9fi"

# %% [markdown]
# # Download vocabulary

# %% [markdown]
# I got this from Vincent who got it from Aki
#
# NOT FOR SHARING !!!
#
# to `folder_path`

# %% [markdown]
# # Parse to feather

# %%
#CONCEPT.csv
file="icd9_SimoP.txt"

data <- read_delim(file.path(folder_path,file), "\t")
# Out:
# Parsed with column specification:
# cols(
#   ICD9 = col_character(),
#   ICD9LYH = col_character(),
#   ICD9TXT = col_character()
# )

# %%
feather::write_feather(data, file.path(folder_path,"FINNGEN_ICD9fi.feather") )

# %%
data
# Out:
#      ICD9  ICD9LYH
# 1    001   KOLERA
# 2    0010A KOLERA VIBR CHOLE O1
# 3    0011A KOLERA EL TOR (O1)
# 4    0019X KOLERA NUD
# 5    002   FEB TYPHOID/PARATYPH
# 6    0020A FEBRIS TYPHOIDES
# 7    0021A FEB PARATYPH TYPUS A
# 8    0022A FEB PARATYPH TYPUS B
# 9    0023A FEB PARATYPH TYPUS C
# 10   0029X FEB PARATYPHOID NUD
# 11   003   SALMONELLOSIS ALIA
# 12   0030A GASTROENTER SALMONEL
# 13   0031A SEPTICHAEM SALMONELL
# 14   0032A MENINGITIS SALMONELL
# 15   0032B PNEUMONIA SALMONELLO
# 16   0032C ARTHRITIS SALMONELLO
# 17   0032D OSTEOMYELIT SALMONEL
# 18   0038X SALMONELLOSIS ALIA
# 19   0039X SALMONELLOSIS NUD
# 20   004   SHIGELLOSIS
# 21   0040A SHIGELLOSIS TYPUS A
# 22   0041A SHIGELLOSIS TYPUS B
# 23   0042A SHIGELLOSIS TYPUS C
# 24   0043A SHIGELLOSIS TYPUS D
# 25   0048X SHIGELLOSIS ALIA
# 26   0049X SHIGELLOSIS NUD
# 27   005   INTOXIC ALIMENTARIA
# 28   0050A STAFYLOK RUOKAMYRKYT
# 29   0051A BOTULISMI
# 30   0052A CLOSTR PERFR RUOKAMY
# ...  ...   ...
# ...
